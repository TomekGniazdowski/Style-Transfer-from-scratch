# %%
from experiments_utils import experiment_vgg19

# %% [markdown]
# ### Style 1

# %%
experiment_vgg19(
    img_content_path='../data/content_imgs/content_1.png',
    img_style_path='../data/style_imgs/style_1.jpeg',
    img_height=400,
    initial_image_distribution='normal_distr',
    content_weight=5e3,
    style_weight=5,
    total_variation_weight=1e-4,
    max_iter=1000,
    experiment_name='ex1/style_1'
)
# Out:
# content image shape: torch.Size([1, 3, 400, 533]) style image shape: torch.Size([1, 3, 400, 560])
# /home/tgniazdo/GITHUB/Style Transfer (from scratch)/.venv/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/tgniazdo/GITHUB/Style Transfer (from scratch)/.venv/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 100:                     Loss: 309335008.0,                     CL: 37107.2,                     SL: 24757944.0,                     TVL: 94309152.0
# ...

# %% [markdown]
# ### Style 2

# %%
experiment_vgg19(
    img_content_path='../data/content_imgs/content_1.png',
    img_style_path='../data/style_imgs/style_2.jpg',
    img_height=400,
    initial_image_distribution='normal_distr',
    content_weight=1e4,
    style_weight=1,
    total_variation_weight=1e-5,
    max_iter=1000,
    experiment_name='ex1/style_2'
)
# Out:
# content image shape: torch.Size([1, 3, 400, 533]) style image shape: torch.Size([1, 3, 400, 640])
# Epoch 100:                     Loss: 445706880.0,                     CL: 29444.1,                     SL: 151264448.0,                     TVL: 110855400.0
# Epoch 200:                     Loss: 335436320.0,                     CL: 21902.3,                     SL: 116411800.0,                     TVL: 108907968.0
# Epoch 300:                     Loss: 303973760.0,                     CL: 19694.3,                     SL: 107029768.0,                     TVL: 108012416.0
# Epoch 400:                     Loss: 290184064.0,                     CL: 18703.3,                     SL: 103149840.0,                     TVL: 107568008.0
# Epoch 500:                     Loss: 282406656.0,                     CL: 18143.5,                     SL: 100970272.0,                     TVL: 107301744.0
# ...

# %% [markdown]
# ### Style 3

# %%
experiment_vgg19(
    img_content_path='../data/content_imgs/content_1.png',
    img_style_path='../data/style_imgs/style_3.jpeg',
    img_height=400,
    initial_image_distribution='normal_distr',
    content_weight=1e4,
    style_weight=1e1,
    total_variation_weight=1e-5,
    max_iter=1000,
    experiment_name='ex1/style_3'
)
# Out:
# content image shape: torch.Size([1, 3, 400, 533]) style image shape: torch.Size([1, 3, 400, 316])
# Epoch 100:                     Loss: 1017307008.0,                     CL: 64000.3,                     SL: 37730272.0,                     TVL: 98649120.0
# Epoch 200:                     Loss: 655192448.0,                     CL: 45825.4,                     SL: 19693768.0,                     TVL: 95033952.0
# Epoch 300:                     Loss: 544501760.0,                     CL: 39345.1,                     SL: 15104965.0,                     TVL: 92639168.0
# Epoch 400:                     Loss: 493159232.0,                     CL: 35984.1,                     SL: 13331759.0,                     TVL: 90967840.0
# Epoch 500:                     Loss: 468017792.0,                     CL: 34263.7,                     SL: 12537961.0,                     TVL: 89846496.0
# ...

# %% [markdown]
# ### Style 4

# %%
experiment_vgg19(
    img_content_path='../data/content_imgs/content_1.png',
    img_style_path='../data/style_imgs/style_4.jpeg',
    img_height=400,
    initial_image_distribution='normal_distr',
    content_weight=1e4,
    style_weight=5,
    total_variation_weight=1e-5,
    max_iter=1000,
    experiment_name='ex1/style_4'
)
# Out:
# content image shape: torch.Size([1, 3, 400, 533]) style image shape: torch.Size([1, 3, 400, 307])
# Epoch 100:                     Loss: 742105856.0,                     CL: 38923.1,                     SL: 70574744.0,                     TVL: 95702064.0
# Epoch 200:                     Loss: 379611712.0,                     CL: 26733.2,                     SL: 22455772.0,                     TVL: 90329136.0
# Epoch 300:                     Loss: 312984800.0,                     CL: 22846.3,                     SL: 16904210.0,                     TVL: 88106608.0
# Epoch 400:                     Loss: 292941888.0,                     CL: 21439.4,                     SL: 15709339.0,                     TVL: 87052088.0
# Epoch 500:                     Loss: 283544448.0,                     CL: 20731.0,                     SL: 15246655.0,                     TVL: 86399328.0
# ...

# %% [markdown]
# ### Style 5

# %%
experiment_vgg19(
    img_content_path='../data/content_imgs/content_1.png',
    img_style_path='../data/style_imgs/style_5.jpeg',
    img_height=400,
    initial_image_distribution='normal_distr',
    content_weight=1e4,
    style_weight=5,
    total_variation_weight=1e-5,
    max_iter=1000,
    experiment_name='ex1/style_5'
)
# Out:
# content image shape: torch.Size([1, 3, 400, 533]) style image shape: torch.Size([1, 3, 400, 608])
# Epoch 100:                     Loss: 1459963392.0,                     CL: 90404.5,                     SL: 111183392.0,                     TVL: 102490256.0
# Epoch 200:                     Loss: 964075648.0,                     CL: 64897.2,                     SL: 63020552.0,                     TVL: 99592248.0
# Epoch 300:                     Loss: 799131456.0,                     CL: 55372.9,                     SL: 49080240.0,                     TVL: 97660176.0
# Epoch 400:                     Loss: 717877504.0,                     CL: 50422.8,                     SL: 42729692.0,                     TVL: 96194776.0
# Epoch 500:                     Loss: 669891584.0,                     CL: 47419.3,                     SL: 39139580.0,                     TVL: 95001264.0
# ...
